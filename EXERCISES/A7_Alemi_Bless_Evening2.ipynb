# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Work.csv")
df
# accessing the csv file
# Out:
#      Name         city    age py-score
# 0    Emma      Kampala     23       90
# 1  Wilber        Mbale     26       75
# 2   Robin         Gulu     25     mine
# 3   Tevor  Livingstone    NaN       89
# 4    Yeko       Tororo     20       94
# 5  Miriam         Arua  Train      NaN
# 6   Jesca      Mbarara     21       84

# %%
df.head(2)
# the first two fields
# Out:
#      Name     city age py-score
# 0    Emma  Kampala  23       90
# 1  Wilber    Mbale  26       75

# %%
df.tail(2)
# the last Two values
# Out:
#      Name     city age py-score
# 5  Miriam     Arua   0        0
# 6   Jesca  Mbarara  21       84

# %%
df.describe()
# Description of the dataset
# Out:
#         Name     city age py-score
# count      7        7   6        6
# unique     7        7   6        6
# top     Emma  Kampala  23       90
# freq       1        1   1        1

# %%
df.isnull().sum()
# checking for null values.
# Out:
# Name        0
# city        0
# age         1
# py-score    1
# dtype: int64

# %%
df.drop_duplicates()
# removing duplicates
# Out:
#      Name         city    age py-score
# 0    Emma      Kampala     23       90
# 1  Wilber        Mbale     26       75
# 2   Robin         Gulu     25     mine
# 3   Tevor  Livingstone    NaN       89
# 4    Yeko       Tororo     20       94
# 5  Miriam         Arua  Train      NaN
# 6   Jesca      Mbarara     21       84

# %%
df['age'].replace(to_replace="Train", value=0, inplace=True)
# replaces wrong values i the age column

# %%
df['py-score'].replace(to_replace="mine", value=0, inplace=True)
# replaces wrong values i the py-score column

# %%
df.fillna(value=0, inplace=True)
# filling the null values with value = 0

# %%
df
# Out:
#      Name         city age py-score
# 0    Emma      Kampala  23       90
# 1  Wilber        Mbale  26       75
# 2   Robin         Gulu  25        0
# 3   Tevor  Livingstone   0       89
# 4    Yeko       Tororo  20       94
# 5  Miriam         Arua   0        0
# 6   Jesca      Mbarara  21       84
